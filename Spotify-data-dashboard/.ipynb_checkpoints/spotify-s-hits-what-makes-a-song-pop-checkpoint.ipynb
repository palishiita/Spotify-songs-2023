# %% [markdown]
# ![Top 10 Most Streamed Songs](https://i.imgur.com/Vk57hQ6.png)
# ## 🎶 **What to Explore in This Notebook** 🎶
#
# ### 🥇 **1. Top 10 Most Streamed Songs**
# Identify which songs have been streamed the most.
#
# ### 🥇 **2. Top 10 Charting Artists**
# Discover the artists who dominate the charts and playlists.
#
# ### 🎵 **3. Exploring Key and Mode Distributions**
# Dive into the world of musical keys and modes, exploring their prevalence and popularity in the charts.
#
# ### 🕺 **4. Danceability, Valence, and BPM vs. Popularity**
# Explore the interplay between danceability, emotional valence, tempo, and their collective impact on song popularity.
#
# ### 🎼 **5. Acousticness, Instrumentalness, Liveness, and Speechiness Analysis**
# Unpack the correlation between these musical features and streaming success on Spotify.
#
# ### 🎵 **6. A Dive into the Top Songs and Artists**
# Explore clusters to uncover patterns in song popularity across various platforms, discerning the symphony of factors that harmonize to produce a hit.
#
# *Clean_spotify_2023 is the clean verson of spotify-2023.
# Manually enocoding special characters in song and artist columns.
# The stream number of Edison Lighthouse is corrupt; replace by average number.*
#
# --------------------------------------------------------------------------------

# %% [markdown]
# ## **1. Identify which songs have been streamed the most.**

# %%
import pandas as pd

file_path = '/kaggle/input/clean-spotify-2023-most-stream/Clean_spotify_2023.csv'
spotify_data = pd.read_csv(file_path)

# Converting the 'streams' column to numerical format
spotify_data['streams'] = spotify_data['streams'].str.replace(',', '').astype(int)

# Identifying the top 10 most streamed songs
top_10_songs = spotify_data.nlargest(10, 'streams')[['track_name', 'artist(s)_name', 'streams']]
print(top_10_songs)
# Out:
#                                       track_name  \
# 0                                Blinding Lights
# 1                                   Shape of You
# 2                              Someone You Loved
# 3                                   Dance Monkey
# 4  Sunflower - Spider-Man: Into the Spider-Verse
# 5                                      One Dance
# 6                      STAY (with Justin Bieber)
# 7                                       Believer
# 8                                         Closer
# 9                                        Starboy
#
#                  artist(s)_name     streams
# 0                    The Weeknd  3703895074
# 1                    Ed Sheeran  3562543890
# 2                 Lewis Capaldi  2887241814
# 3                   Tones and I  2864791672
# 4         Post Malone, Swae Lee  2808096550
# 5           Drake, WizKid, Kyla  2713922350
# 6  Justin Bieber, The Kid Laroi  2665343922
# 7               Imagine Dragons  2594040133
# ...

# %% [markdown]
# ## 🥇 **Top 10 Most Streamed Songs**
# | Rank | Track Name                                      | Artist(s) Name               | Streams      |
# |------|-------------------------------------------------|------------------------------|--------------|
# | 1    | [Blinding Lights](https://www.youtube.com/watch?v=4NRXx6U8ABQ)                                 | The Weeknd                   | 3,703,895,074|
# | 2    | [Shape of You](https://www.youtube.com/watch?v=JGwWNGJdvx8)                                    | Ed Sheeran                   | 3,562,543,890|
# | 3    | [Someone You Loved](https://www.youtube.com/watch?v=zABLecsR5UE)                               | Lewis Capaldi                | 2,887,241,814|
# | 4    | [Dance Monkey](https://www.youtube.com/watch?v=q0hyYWKXF0Q)                                    | Tones and I                  | 2,864,791,672|
# | 5    | [Sunflower - Spider-Man: Into the Spider-Verse](https://www.youtube.com/watch?v=ApXoWvfEYVU)   | Post Malone, Swae Lee        | 2,808,096,550|
# | 6    | [One Dance](https://www.youtube.com/watch?v=vcer12OFU2g)                                       | Drake, WizKid, Kyla          | 2,713,922,350|
# | 7    | [STAY (with Justin Bieber)](https://www.youtube.com/watch?v=kTJczUoc26U)                       | Justin Bieber, The Kid Laroi | 2,665,343,922|
# | 8    | [Believer](https://www.youtube.com/watch?v=7wtfhZwyrcc)                                        | Imagine Dragons              | 2,594,040,133|
# | 9    | [Closer](https://www.youtube.com/watch?v=0zGcUoRlhmw)                                          | The Chainsmokers, Halsey     | 2,591,224,264|
# | 10   | [Starboy](https://www.youtube.com/watch?v=34Na4j8AVgA)                                         | The Weeknd, Daft Punk        | 2,565,529,693|
#
# * **Pop music dominates the list.** 8 out of the 10 songs are pop songs, with the only exceptions being "Sunflower - Spider-Man: Into the Spider-Verse" (hip hop/pop) and "One Dance" (dancehall/pop). This suggests that pop music is still the most popular genre of music on Spotify.
# * **The Weeknd is the most streamed artist on the list.** Two of his songs, "Blinding Lights" and "Starboy," are in the top 10. This suggests that The Weeknd is one of the most popular artists on Spotify.
# * **Collaboration songs are popular on the list.** 4 out of the 10 songs are collaboration songs, featuring artists from different genres. This suggests that collaboration songs are popular with Spotify listeners.
# * **Songs from movies and video games are popular on the list.** 2 out of the 10 songs are from movies and video games: "Sunflower - Spider-Man: Into the Spider-Verse" and "One Dance" (which was featured in the movie "Finding Dory"). This suggests that songs from movies and video games are also popular with Spotify listeners.
# * **Older songs are still popular on the list.** 3 out of the 10 songs were released in 2017 or earlier: "Shape of You" (2017), "Someone You Loved" (2018), and "Believer" (2017). This suggests that older songs are still popular with Spotify listeners, even if they are not as newsworthy as newer songs.
#
# Overall, the list of top 10 most streamed songs on Spotify provides a snapshot of the most popular music on the platform. It is clear that pop music is still the most popular genre, and that collaboration songs and songs from movies and video games are also popular. Additionally, older songs are still popular with Spotify listeners.

# %% [markdown]
# ## **2. Discover the artists who dominate the charts and playlists.**
#
# #### **Steps**
# 1. Importing the essential libraries for data manipulation (`pandas`) and visualization (`matplotlib` and `seaborn`).
# 2. Load the dataset into a Pandas DataFrame.
# 3. Given songs can have multiple artists so split and count each artist individually.
# 4. Visualize the top 10 artists with the most songs in our dataset using a bar plot.

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

file_path = '/kaggle/input/clean-spotify-2023-most-stream/Clean_spotify_2023.csv'
data = pd.read_csv(file_path)

# Calculate the frequency of each artist in the dataset
# Split songs by multiple artists and count each artist separately.
artist_count = data['artist(s)_name'].str.split(', ').explode().value_counts()

# Visualize the artists who are most frequently
sns.set_style("whitegrid")

plt.figure(figsize=(10, 6))
sns.barplot(y=artist_count.index[:10], x=artist_count.values[:10], palette="viridis", orient="h")


plt.title('Top 10 Charting Artists in the Dataset', fontsize=16)
plt.xlabel('Number of Songs', fontsize=12)
plt.ylabel('Artist Name', fontsize=12)

plt.show()

# %% [markdown]
# ## 🥇 **Top 10 Charting Artists**
#
# | Artist       | Genre(s)                       | Notable Achievements        | Collaborations        | Unique Aspect                                       |
# |--------------|--------------------------------|-----------------------------|-----------------------|-----------------------------------------------------|
# | [Bad Bunny](https://www.youtube.com/@BadBunnyPR)    | Reggaeton, Trap, Latin pop, Pop| Multiple Latin Grammy Awards| Jhay Cortez, Cardi B  | Puerto Rican artist known for his distinctive voice and fashion sense |
# | [Taylor Swift](https://www.youtube.com/@TaylorSwift) | Pop, Country, Folk             | 10 Grammy Awards            | Ed Sheeran, Brendon Urie | Known for her narrative songwriting                         |
# | [The Weeknd](https://www.youtube.com/@TheWeeknd)   | R&B, Pop, Alternative R&B      | 3 Grammy Awards             | Daft Punk, Ariana Grande | Known for his wide vocal range and mysterious persona        |
# | [SZA](https://www.youtube.com/@sza)          | R&B, Soul, Neo-soul            | Multiple Grammy nominations | Travis Scott, Kendrick Lamar | Known for her unique voice and introspective lyrics          |
# | [Kendrick Lamar](https://www.youtube.com/@kendricklamar) | Hip Hop, Jazz Rap, Spoken word, Pop | 13 Grammy Awards        | SZA, Drake            | Known for his lyrical complexity and social commentary       |
# | [Feid](https://www.youtube.com/@Feid)         | Reggaeton, Trap, Pop           | Notable singles in Latin America | J Balvin, Sech   | Colombian artist making waves in the urban music scene      |
# | [Drake](https://www.youtube.com/@DrakeOfficial)        | Hip hop, R&B, Pop              | 4 Grammy Awards             | Rihanna, Lil Wayne    | Known for his emotional and introspective lyrics             |
# | [Harry Styles](https://www.youtube.com/@HarryStyles) | Pop, Rock, Soul                | Multiple chart-topping singles | Stevie Nicks      | Known for his fashion sense and solo success post-One Direction |
# | [Peso Pluma](https://www.youtube.com/@pesopluma_oficial)   | Reggaeton, Trap, Latin pop     | Multiple Top Latin Artist Awards | Snoop Dogg, Natanael Cano | Unique fashion sense and energetic live performances, ability to mix different genres |
# | [Metro Boomin](https://www.youtube.com/@metroboomin) | Hip Hop, Trap, R&B             | Produced hits for top artists | 21 Savage, Offset, Future | One of the most sought-after producers in hip-hop          |
#
# --------------------------------------------------------------------------------

# %% [markdown]
# ## **3. Dive into the world of musical keys and modes, exploring their prevalence and popularity in the charts.**
#
# #### **Variables Explanation**:
# * **key**: Key of the song
# * **mode**: Mode of the song (major or minor)
#
# #### **Step**
# 1. **Import Necessary Libraries**: `pandas` for data manipulation, `matplotlib` for plotting, and `seaborn` for statistical visualizations.
# *Repeat the importing libraries step here so you can use each section snippet code individually.*
#
# 2. **Handling Missing Values**: Omit rows with missing 'key' values.
# *Use Google sheet build-in function and find out there are 95 missing values in the 'key' column.*
#
# 3. **Visualization** of Key and Mode Distributions
#
# 4. **Create two subplots** side by side for the key and mode distributions with Spotify theme colou.

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

data = pd.read_csv('/kaggle/input/clean-spotify-2023-most-stream/Clean_spotify_2023.csv')

# Check for missing values in relevant columns
print(data[['key', 'mode']].isnull().sum())

# Drop rows with missing 'key' values
data = data.dropna(subset=['key'])

fig, axes = plt.subplots(1, 2, figsize=(14, 6))

spotify_green = "#1DB954"

# Visualizing distribution of keys
sns.countplot(x='key', data=data, order=sorted(data['key'].unique()), ax=axes[0], palette=[spotify_green])
axes[0].set_title('Distribution of Songs Across Different Keys')
axes[0].set_xlabel('Key')
axes[0].set_ylabel('Count')
axes[0].tick_params(axis='x', rotation=45)

# Visualizing distribution of modes
sns.countplot(x='mode', data=data, order=sorted(data['mode'].unique()), ax=axes[1], palette={"Major": spotify_green, "Minor": "black"})
axes[1].set_title('Distribution of Songs Across Different Modes')
axes[1].set_xlabel('Mode')
axes[1].set_ylabel('Count')

# Adjust the layout
plt.tight_layout()
plt.show()
# Out:
# key     95
# mode     0
# dtype: int64

# %% [markdown]
# ## 🎵 **Exploring Key and Mode Distributions**
#
# ### 🎶 **C# emerges as the champion among musical keys, boasting the highest count of popular songs.**
#
# #### Here are some example songs with **C#** key:
# * [The Weeknd - Blinding Lights](https://www.youtube.com/watch?v=fHI8X4OXluQ)
# * [Ed Sheeran - Shape of You](https://www.youtube.com/watch?v=JGwWNGJdvx8)
# * [Lewis Capaldi - Someone You Loved](https://www.youtube.com/watch?v=zABLecsR5UE)
#
#
# ### 🎶 **D# finds itself less frequented in the realm of chart-toppers, seizing the spot for the least utilized key among the analyzed tracks.**
#
# #### Here are some example songs with **D#** key:
# * [Imagine Dragons - Demons](https://www.youtube.com/watch?v=mWRsgZuwf_8)
# * [Lil Nas X, Jack Harlow - INDUSTRY BABY](https://www.youtube.com/watch?v=UTHLKHL_whs)
# * [Lewis Capaldi - Before You Go](https://www.youtube.com/watch?v=Jtauh8GcxBY)
#
# I know nothing about the music and its composition, so I asked Bard "What's the difference between C# and D3"
#
# ### **Bard answered:**
# *A composer might choose to write in the key of C# because it has a brighter and more cheerful sound.*
# *On the other hand, they might choose to write in the key of D# because it has a darker and more somber sound.*
#
# --------------------------------------------------------------------------------

# %% [markdown]
# ## **4. Danceability, emotional Valence, Bpm VS. Impact on song popularity.**
#
# #### **Variables Explanation**:
# * **danceability**: Percentage indicating how suitable the song is for dancing
# * **valence**: Positivity of the song's musical content
# * **bpm**: Beats per minute, a measure of song tempo
#
# #### **Steps**:
# 1. **Import Necessary Libraries**: `pandas` for data manipulation, `matplotlib` for plotting, and `seaborn` for statistical visualizations.
# *Repeat the importing libraries step here so you can use each section snippet code individually.*
#
# 2. **Data Cleaning and Pre-processing:**
# Handle missing or non-numeric entries to facilitate accurate analysis.
#
# 3. **Correlation Computation and Heatmap Visualization:**
# Implement visualizations to observe the distributions of 'danceability', 'valence', 'BPM', and 'streams'.

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

file_path = '/kaggle/input/top-spotify-songs-2023/spotify-2023.csv'
spotify_data = pd.read_csv(file_path, encoding='ISO-8859-1')

# The stream data of "Love Grows" is corrupt
# Convert columns to numeric type, coercing errors to NaN
spotify_data['bpm'] = pd.to_numeric(spotify_data['bpm'], errors='coerce')
spotify_data['danceability_%'] = pd.to_numeric(spotify_data['danceability_%'], errors='coerce')
spotify_data['valence_%'] = pd.to_numeric(spotify_data['valence_%'], errors='coerce')
spotify_data['streams'] = pd.to_numeric(spotify_data['streams'], errors='coerce')

# Handle NaN values by removing them
spotify_data = spotify_data.dropna(subset=['bpm', 'danceability_%', 'valence_%', 'streams'])

# Correlation matrix
corr_matrix = spotify_data[['bpm', 'danceability_%', 'valence_%', 'streams']].corr()

# Create a custom color palette with potify green
cmap_spotify = sns.light_palette("#1DB954", as_cmap=True)

# Set up the matplotlib figure
plt.figure(figsize=(10, 8))

# Draw the heatmap with the mask and correct aspect ratio
sns.heatmap(corr_matrix, cmap=cmap_spotify, vmax=.3, center=0,
            square=True, linewidths=.5, cbar_kws={"shrink": .5}, annot=True)

# Titles and labels
plt.title('Correlation Heatmap of Song Characteristics and Popularity', fontsize=16)
plt.xticks(fontsize=12)
plt.yticks(fontsize=12)

# Show plot
plt.show()

# %% [markdown]
# ## 🕺 **Danceability, Valence, and BPM vs. Popularity relationship is WEAK!!**
# ### 🎶 **Music has free soul!**
# The correlation analysis revealed generally weak relationships between the song characteristics of danceability, valence, and BPM with the number of streams on Spotify, indicating that these characteristics alone might not be strong predictors of a song's popularity.
#
# The heatmap unveiled a notable tie between danceability and valence at positive (0.41). The more a song makes you want to dance, the more upbeat its vibe likely is.
#
# ### [Mae Stephens - If We Ever Broke Up](https://www.youtube.com/watch?v=TbGT3d0pHgo)
# * danceability - 90%
# * valence - 96%
# --------------------------------------------------------------------------------

# %% [markdown]
# ## **5. Analysis of Acousticness, Instrumentalness, Liveness, and Speechiness in Relation to Popularity on Spotify**
#
# #### **Variables Explanation**:
# * **acousticness**: Amount of acoustic sound in the song
# * **instrumentalness**: Amount of instrumental content in the song
# * **liveness**: Presence of live performance elements
# * **speechiness**: Amount of spoken words in the song
#
# #### **Steps**:
# 1. **Import Necessary Libraries**: `pandas` for data manipulation, `matplotlib` for plotting, and `seaborn` for statistical visualizations.
#
# *Repeat the importing libraries step here so you can use each section snippet code individually.*
#
# 2. **Load and Preprocess Data**
#
# 3. **Calculate Correlations**
#
# 4. **Visualize Relationships with Scatter Plots**

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

#Load and clean data
data = pd.read_csv('/kaggle/input/top-spotify-songs-2023/spotify-2023.csv', encoding='ISO-8859-1')
data['streams'] = pd.to_numeric(data['streams'], errors='coerce')
data = data.dropna(subset=['streams'])
data['streams'] = data['streams'].astype(int)

# Calculate the correlation
correlation_columns = ['acousticness_%', 'instrumentalness_%', 'liveness_%', 'speechiness_%']
correlations = data[['streams'] + correlation_columns].corr().loc['streams', correlation_columns]

# Set the Visualization
sns.set_style("whitegrid")
plt.figure(figsize=(15, 10))
features = ['acousticness_%', 'instrumentalness_%', 'liveness_%', 'speechiness_%']

# Create subplots for each feature
for i, feature in enumerate(features, 1):
    plt.subplot(2, 2, i)
    sns.scatterplot(x=data[feature], y=data['streams'])
    plt.title(f'Streams vs {feature}')
    plt.xlabel(feature)
    plt.ylabel('Streams')
    # Displaying the correlation on the plot
    plt.annotate(f"Corr: {correlations[feature]:.2f}", 
                 xy=(0.7, 0.9), xycoords='axes fraction', fontsize=12)

plt.tight_layout()
plt.show()

# %% [markdown]
# ## 🎼 **Acousticness, Instrumentalness, Liveness, and Speechiness**
# ### 🎶 **Music has free soul!**
# All of these correlations are negative and very weak. The correlation with Acousticness_% is too weak and close to zero. There isn't a strong linear relationship between the number of streams and any of the four features, which is consistent with the low correlation coefficients.
#
# 🎵 Songs with  **High acousticness percentage** are likely to be performed with acoustic instruments, such as guitars and pianos. This is consistent with the song's folk style.
#
# * [Lord Huron - The Night We Met](https://www.youtube.com/watch?v=KtlgYxa6BMU)
# * Highest acousticness percentage in this dataset - 97%
#
# 🎵 Songs with  **High instrumentalness percentagevery** are likely to be instrumental, with little or no vocals. This is consistent with the song's post-punk genre.
#
# * [Vundabar - Alien Blues](https://www.youtube.com/watch?v=V8fYAAh5uuA)
# * Highest instrumentalness percentage in this dataset - 91%
#
# 🎵 Songs with  **High liveness percentage** are likely to be a live recording, with the associated background noise and audience interaction. This is consistent with the song's sertanejo genre, which is known for its live performances.
#
# * [George Henrique e Rodrigo Feat. Marília Mendonça - Vai Lá Em Casa Hoje](https://www.youtube.com/watch?v=r2ma8WPRppk) 🇧🇷
# * Highest liveness percentage in this dataset - 97%
#
# 🎵 Songs with  **High speechiness percentage** are  likely to contain spoken word, such as rapping or singing. This is consistent with the song's funk genre, which is often characterized by its rap vocals.
#
# * [MC Caverinha, Kayblack, Wall Hein - Cartão Black](https://www.youtube.com/watch?v=OZgQnRcGZXs)
# * Highest speechiness percentage in this dataset - 64%

# %% [markdown]
# ## **6. Exploring Song Popularity Across Various Music Platforms: Part 1**
#
# #### **Approach**:
# 1. Data Preprocessing:
# Handle missing or non-numeric entries to ensure accurate clustering.
# Normalize the data to mitigate the impact of the scale of variables.
#
# 2. Hierarchical Clustering & Dendrogram:
# Utilize hierarchical clustering to build a dendrogram, aiding in visual identification of natural groupings within the data.
# Determine the optimal number of clusters by interpreting the dendrogram.
#
# 3. PCA for Data Visualization:
# Implement Principal Component Analysis (PCA) to reduce the dimensionality of the data, enabling visualization in a 2D space.
# Visualize clusters to observe how songs group together based on the chosen features.
#
# 4. Cluster Analysis:
# Analyze the characteristics of each cluster by examining the mean values of the features.
#
# #### **Features Utilized**:
# in_spotify_playlists
# in_spotify_charts
# in_apple_playlists
# in_apple_charts
# in_deezer_playlists
# in_deezer_charts
# in_shazam_charts
# streams

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.cluster import KMeans
from sklearn.preprocessing import StandardScaler

#Load and clean data
data = pd.read_csv('/kaggle/input/top-spotify-songs-2023/spotify-2023.csv', encoding='ISO-8859-1')
data['streams'] = pd.to_numeric(data['streams'], errors='coerce')
data = data.dropna(subset=['streams'])
data['streams'] = data['streams'].astype(int)

# Features to use for clustering
features = ['acousticness_%', 'instrumentalness_%', 'liveness_%', 'speechiness_%', 'danceability_%', 'valence_%', 'bpm']

# Scaling the features
scaler = StandardScaler()
data_scaled = scaler.fit_transform(data[features])

sse = []
possible_k_values = range(2, 11)

for k in possible_k_values:
    kmeans = KMeans(n_clusters=k, n_init=10, random_state=42)
    kmeans.fit(data_scaled)
    sse.append(kmeans.inertia_)

# Plotting the Elbow Method graph
plt.figure(figsize=(10, 6))
sns.lineplot(x=possible_k_values, y=sse, marker='o')
plt.title('Elbow Method For Optimal k')
plt.xlabel('k')
plt.ylabel('Sum of Squared Distances')
plt.show()

# Apply K-Means with the optimal k
optimal_k = 3
kmeans = KMeans(n_clusters=optimal_k, n_init=10, random_state=42)
data['cluster'] = kmeans.fit_predict(data_scaled)

# Analyzing the clusters
cluster_summary = data.groupby('cluster')[features].mean()

# Visualizing the clusters
# For example, let's plot 'danceability' vs 'valence', colored by cluster
plt.figure(figsize=(10, 6))
sns.scatterplot(x=data['danceability_%'], y=data['valence_%'], hue=data['cluster'], palette='viridis', s=50)
plt.title('Clusters Visualized by Danceability and Valence')
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import scipy.cluster.hierarchy as sch
from sklearn.cluster import AgglomerativeClustering
from sklearn.preprocessing import StandardScaler
from sklearn.decomposition import PCA

# Load and clean data
data = pd.read_csv('/kaggle/input/top-spotify-songs-2023/spotify-2023.csv', encoding='ISO-8859-1')
data['streams'] = pd.to_numeric(data['streams'], errors='coerce')
data = data.dropna(subset=['streams'])
data['streams'] = data['streams'].astype(int)

# Features for clustering
features = [
    'in_spotify_playlists', 'in_spotify_charts',
    'in_apple_playlists', 'in_apple_charts',
    'in_deezer_playlists', 'in_deezer_charts',
    'in_shazam_charts', 'streams'
]

# Convert string columns to integer
data[features] = data[features].apply(lambda x: pd.to_numeric(x.astype(str)
                                                .str.replace(',',''), errors='coerce'))

# Handling NaN values after conversion
data = data.dropna(subset=features)

# Scaling the features
scaler = StandardScaler()
data_scaled = scaler.fit_transform(data[features])

# Creating a Dendrogram
plt.figure(figsize=(10, 7))
dendrogram = sch.dendrogram(sch.linkage(data_scaled, method='ward'))
plt.title('Dendrogram')
plt.xlabel('Songs')
plt.ylabel('Euclidean Distances')
plt.show()

# Applying Hierarchical Clustering
# (Choose n_clusters based on the dendrogram)
hc = AgglomerativeClustering(n_clusters=3, metric='euclidean', linkage='ward')
data['hierarchical_cluster'] = hc.fit_predict(data_scaled)

# Analyzing the Clusters
cluster_summary = data.groupby('hierarchical_cluster')[features].mean()
print(cluster_summary)

# Apply PCA and fit the features
pca = PCA(n_components=2)
principal_components = pca.fit_transform(data_scaled)

# Create a DataFrame with the principal components
pc_df = pd.DataFrame(data=principal_components, columns=['PC1', 'PC2'])

# Add the cluster label obtained from hierarchical clustering to this DataFrame
pc_df['Cluster'] = data['hierarchical_cluster']

# Visualizing the 2D projection
plt.figure(figsize=(10, 7))
sns.scatterplot(x=pc_df['PC1'], y=pc_df['PC2'], hue=pc_df['Cluster'], palette='viridis', s=50)
plt.title('2D PCA of Song Clusters')
plt.show()
# Out:
#                       in_spotify_playlists  in_spotify_charts  \
# hierarchical_cluster
# 0                              4207.290909          37.478788
# 1                              2229.026856           4.598736
# 2                             21388.769231          15.605769
#
#                       in_apple_playlists  in_apple_charts  \
# hierarchical_cluster
# 0                              80.466667        99.169697
# 1                              34.413902        33.260664
# 2                             187.913462        75.490385
#
#                       in_deezer_playlists  in_deezer_charts  in_shazam_charts  \
# hierarchical_cluster
# 0                              185.666667         10.824242        227.254545
# 1                               66.420221          0.431280         16.274882
# 2                             2401.269231          2.105769         61.317308
#
#                            streams
# hierarchical_cluster
# 0                     4.857125e+08
# ...

# %% [markdown]
# **Cluster 0** has a medium number of Spotify playlists, the highest rank in Spotify charts, medium-level presence in Apple and Deezer playlists, and charts, and a high rank in Shazam charts. The streams are also quite significant, making this a cluster of fairly popular songs.
#
# **Cluster 1** has the lowest presence and ranks across all platforms and the lowest number of streams, implying these are the less popular songs.
#
# **Cluster 2** has the highest presence in Spotify, Apple, and Deezer playlists, a medium rank in their respective charts, and a decent rank in Shazam charts. This cluster also has the highest number of streams, making it the cluster of the most popular songs.

# %% [markdown]
# ## **6. Exploring Song Popularity Across Various Music Platforms: Part 2**
#
# #### **Background**:
# Through clustering, we grouped songs based on certain features (e.g., streaming numbers, presence in various platform charts, and playlists) to identify patterns or similarities among them. Each cluster represents a group of songs that share similarities across these features, potentially indicating similar user behavior and popularity patterns across different platforms.
#
# #### **What is a Cluster in This Context?**
# In the realm of our analysis, a **cluster** is a collection of songs that share similar characteristics related to their popularity and presence on various music platforms, such as Spotify and Apple Music. Songs within the same cluster exhibit similar behaviors in terms of streams, presence in charts, and inclusion in playlists across these platforms.
#
# #### **Exploring Top Songs and Artists:**
# We delve into each cluster to identify the top songs and artists, aiming to glean insights into the specific tracks and musicians that characterize each group. This exploration may reveal specific artists or tracks that tend to align with the popularity and platform presence patterns encapsulated by each cluster.
#
# #### **Steps**:
# 1. **Identify Top Songs and Artists**:
#    Extract and list the most streamed songs and most recurrent artists within each cluster to understand the kind of music that is popular within the respective group.
#
# 2. **Analyze & Interpret**:
#    Investigate the listed songs and artists, seeking patterns or commonalities. For instance, do certain artists tend to appear in a specific cluster? Are there observable trends in the genre or style of the top songs?
#
# #### **Significance**:
# Understanding the top songs and artists within each cluster not only unveils the specific tracks and musicians that define each group but also potentially highlights trends in user behavior and music popularity across different platforms.

# %%
# Number of top songs and artists to display
top_n = 10

# Loop through each cluster
for cluster in data['hierarchical_cluster'].unique():
    subset_data = data[data['hierarchical_cluster'] == cluster]
    
    print(f"\nCluster {cluster}:")
    print(f"Top {top_n} Songs:")
    print(subset_data.nlargest(top_n, 'streams')['track_name'])
    
    print(f"\nTop {top_n} Artists:")
    print(subset_data['artist(s)_name'].value_counts().head(top_n))
# Out:
# Cluster 0:
# Top 10 Songs:
# 84                 STAY (with Justin Bieber)
# 47                               Die For You
# 106                  Cold Heart - PNAU Remix
# 87                           Me Porto Bonito
# 246                               Easy On Me
# 74     Quevedo: Bzrp Music Sessions, Vol. 52
# 12                                   Flowers
# 22                          I Wanna Be Yours
# 152                             Danza Kuduro
# 192                        Titi Me Preguntï¿
# Name: track_name, dtype: object
#
# Top 10 Artists:
# artist(s)_name
# NewJeans                    5
# Bad Bunny                   5
# Taylor Swift                4
# Lana Del Rey                3
# Karol G                     3
# SZA                         3
# Feid                        3
# Rauw Alejandro, Bizarrap    2
# Fifty Fifty                 2
# Beyoncï¿                    2
# Name: count, dtype: int64
#
# Cluster 2:
# Top 10 Songs:
# ...

# %% [markdown]
# ## 🎵 **A Dive into the Top Songs and Artists**
#
# ### **Cluster 2: High Popularity, Especially on Streaming Platforms**
# * Spotify: Highest presence in playlists and moderate ranking in charts.
# * Apple Music: Highest presence in playlists and charts.
# * Deezer: Highest presence in playlists and charts.
# * Shazam: Moderate ranking in charts.
# * Streams: Highest streaming numbers, indicating high popularity.
#
# #### **Top 10 Songs:**
#
# | Rank | Song Name                                           |
# |------|-----------------------------------------------------|
# | 1    | Shape of You                                        |
# | 2    | Sunflower - Spider-Man: Into the Spider-Verse       |
# | 3    | One Dance                                           |
# | 4    | Believer                                            |
# | 5    | Closer                                              |
# | 6    | Starboy                                             |
# | 7    | Perfect                                             |
# | 8    | Señorita                                            |
# | 9    | Say You Won't Let Go                                |
# | 10   | lovely - Bonus Track                                |
#
# #### **Top 10 Artists:**
#
# | Rank | Artist(s) Name        | Count |
# |------|-----------------------|-------|
# | 1    | Taylor Swift          | 5     |
# | 2    | Ed Sheeran            | 4     |
# | 3    | Eminem                | 3     |
# | 4    | Coldplay              | 3     |
# | 5    | The Weeknd            | 3     |
# | 6    | Arctic Monkeys        | 3     |
# | 7    | Dr. Dre, Snoop Dogg   | 2     |
# | 8    | Avicii                | 2     |
# | 9    | Justin Bieber         | 2     |
# | 10   | Dua Lipa              | 2     |
# --------------------------------------------------------------------------------
# ### **Cluster 0: Moderate Popularity Across Platforms**
# * Spotify: Moderate presence in playlists and high ranking in charts.
# * Apple Music: Moderate presence in playlists and decent ranking in charts.
# * Deezer: Moderate presence in playlists and charts.
# * Shazam: High ranking in charts.
# * Streams: Substantial streaming numbers, indicating a good level of popularity.
#
# #### **Top 10 Songs:**
#
# | Rank | Song Name                                       |
# |------|-------------------------------------------------|
# | 1    | STAY (with Justin Bieber)                       |
# | 2    | Die For You                                     |
# | 3    | Cold Heart - PNAU Remix                         |
# | 4    | Me Porto Bonito                                 |
# | 5    | Easy On Me                                      |
# | 6    | Quevedo: Bzrp Music Sessions, Vol. 52           |
# | 7    | Flowers                                         |
# | 8    | I Wanna Be Yours                                |
# | 9    | Danza Kuduro                                    |
# | 10   | Tití Me Preguntó                                |
#
# #### **Top 10 Artists:**
#
# | Rank | Artist(s) Name          | Count |
# |------|-------------------------|-------|
# | 1    | NewJeans                | 5     |
# | 2    | Bad Bunny               | 5     |
# | 3    | Taylor Swift            | 4     |
# | 4    | Lana Del Rey            | 3     |
# | 5    | Karol G                 | 3     |
# | 6    | SZA                     | 3     |
# | 7    | Feid                    | 3     |
# | 8    | Rauw Alejandro, Bizarrap| 2     |
# | 9    | Fifty Fifty             | 2     |
# | 10   | Beyoncé                 | 2     |
#
# --------------------------------------------------------------------------------
# ### **Cluster 1: Low Popularity Across All Platforms**
# * Spotify: Least presence in playlists and lowest ranking in charts.
# * Apple Music: Least presence in playlists and lowest ranking in charts.
# * Deezer: Least presence in playlists and charts.
# * Shazam: Lowest ranking in charts.
# * Streams: Lowest streaming numbers, indicating low popularity.
#
# #### **Top 10 Songs:**
#
# | Rank | Song Name                                             |
# |------|-------------------------------------------------------|
# | 1    | When I Was Your Man                                   |
# | 2    | Locked Out Of Heaven                                  |
# | 3    | Let Me Down Slowly                                    |
# | 4    | Heather                                               |
# | 5    | Iris                                                  |
# | 6    | deja vu                                               |
# | 7    | positions                                             |
# | 8    | Enemy - from the series Arcane League of Legends      |
# | 9    | Hope                                                  |
# | 10   | Contection                                            |
#
# #### **Top 10 Artists:**
#
# | Rank | Artist(s) Name       | Count |
# |------|----------------------|-------|
# | 1    | Taylor Swift         | 25    |
# | 2    | SZA                  | 16    |
# | 3    | The Weeknd           | 14    |
# | 4    | Bad Bunny            | 13    |
# | 5    | Harry Styles         | 13    |
# | 6    | Kendrick Lamar       | 11    |
# | 7    | Morgan Wallen        | 10    |
# | 8    | Drake, 21 Savage     | 8     |
# | 9    | Labrinth             | 7     |
# | 10   | BTS                  | 6     |
